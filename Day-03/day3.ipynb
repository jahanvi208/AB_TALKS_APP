# %%
# !pip install nltk

import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.3)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.tokenize import word_tokenize

text = """ nowadays AI is getting very useful"""

tokens = word_tokenize(text)

print("Original Text:\n", text)
print("\nTokens:\n", tokens)
# Out:
# Original Text:
#   nowadays AI is getting very useful
#
# Tokens:
#  ['nowadays', 'AI', 'is', 'getting', 'very', 'useful']

# %%
from nltk.corpus import stopwords
import string

stop_words = set(stopwords.words('english'))

clean_tokens = []

for word in tokens:
    word = word.lower()
    if word not in stop_words and word not in string.punctuation:
        clean_tokens.append(word)

print("Cleaned Tokens:\n", clean_tokens)
# Out:
# Cleaned Tokens:
#  ['ai', 'transforming', 'world', 'machines', 'learn', 'data', 'make', 'decisions']

# %%
from collections import Counter

bow = Counter(clean_tokens)

print("Bag of Words:\n", bow)
# Out:
# Bag of Words:
#  Counter({'ai': 1, 'transforming': 1, 'world': 1, 'machines': 1, 'learn': 1, 'data': 1, 'make': 1, 'decisions': 1})
